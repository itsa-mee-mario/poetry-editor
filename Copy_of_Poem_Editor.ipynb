# %%
import nltk

# %%
nltk.download('cmudict')
# Out:
# [nltk_data] Downloading package cmudict to /home/s/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# True

# %%
from nltk.corpus import cmudict

# %%
d = cmudict.dict()

# %%
def nsyl(word): 
  # count the number of syllables in a word
  return [len(list(y for y in x if y[-1].isdigit())) for x in d[word.lower()]][0]

# %%
nsyl('legendary')
# Out:
# 4

# %%
with open('content/poem', 'r') as poemfile:
  poemraw = poemfile.readlines()
  poem = []
  for i in poemraw:
    poem.append( i.strip())

# %%
poem
# Out:
# ['I caught it bad yesterday',
#  'You hit me with a call to your place',
#  "Ain't been out in a while anyway",
#  "Was hopin' I could catch you throwin' smiles in my face",
#  "Romantic talkin'? You don't even have to try",
#  "You're cute enough to fuck with me tonight",
#  "Lookin' at the table, all I see is weed and white",
#  "Baby, you livin' the life, but nigga, you ain't livin' right",
#  '',
#  "Cocaine and drinkin' with your friends",
#  'You live in the dark, boy, I cannot pretend',
#  "I'm not fazed, only here to sin",
#  "If Eve ain't in your garden, you know that you can",
#  '',
#  'Call me when you want, call me when you need',
#  "Call me in the morning, I'll be on the way",
#  'Call me when you want, call me when you need',
#  "Call me out by your name, I'll be on the way like",
#  '',
#  'Mmm, mmm, mmm',
#  'Mmm, mmm, mmm',
#  '',
#  'Ayy, ayy',
#  "I wanna sell what you're buyin'",
#  'I wanna feel on your ass in Hawaii',
#  "I want that jet lag from fuckin' and flyin'",
#  "Shoot a child in your mouth while I'm ridin'",
#  'Oh, oh, oh, why me?',
#  'A sign of the times every time that I speak',
#  'A dime and a nine, it was mine every week',
#  "What a time, an incline, God was shinin' on me",
#  "Now I can't leave",
#  "And now I'm actin' hella elite",
#  "Never want the niggas that's in my league",
#  'I wanna fuck the ones I envy, I envy',
#  '',
#  "Cocaine and drinkin' with your friends",
#  'You live in the dark, boy, I cannot pretend',
#  "I'm not fazed, only here to sin",
#  "If Eve ain't in your garden, you know that you can",
#  '',
#  'Call me when you want, call me when you need',
#  "Call me in the morning, I'll be on the way",
#  'Call me when you want, call me when you need',
#  "Call me out by your name, I'll be on the way like",
#  '',
#  'Oh, call me by your name (Mmm, mmm, mmm)',
#  'Tell me you love me in private',
#  'Call me by your name (Mmm, mmm, mmm)',
#  "I do not care if you lyin'",
#  '',
#  "Well I'm just feelin', mm-uh",
#  'I wanna get, mm-uh',
#  "I'm in my, into my, uh",
#  "I'm mm, mm",
#  "I'm still, mm, mm-mm"]

# %%
# sum the number of syllables in each line

poem_syl = []
for sentence in poem:
  line_syl = 0
  for word in sentence.split():
  
    # remove punctuation from word
    word = word.strip(".,!?;:'\"")
    try: line_syl+= nsyl(word)
    except: pass
  poem_syl.append((line_syl, sentence))

# %%
poem_syl
# Out:
# [(7, 'I caught it bad yesterday'),
#  (9, 'You hit me with a call to your place'),
#  (9, "Ain't been out in a while anyway"),
#  (9, "Was hopin' I could catch you throwin' smiles in my face"),
#  (12, "Romantic talkin'? You don't even have to try"),
#  (10, "You're cute enough to fuck with me tonight"),
#  (11, "Lookin' at the table, all I see is weed and white"),
#  (9, "Baby, you livin' the life, but nigga, you ain't livin' right"),
#  (0, ''),
#  (6, "Cocaine and drinkin' with your friends"),
#  (11, 'You live in the dark, boy, I cannot pretend'),
#  (8, "I'm not fazed, only here to sin"),
#  (12, "If Eve ain't in your garden, you know that you can"),
#  (0, ''),
#  (10, 'Call me when you want, call me when you need'),
#  (11, "Call me in the morning, I'll be on the way"),
#  (10, 'Call me when you want, call me when you need'),
#  (12, "Call me out by your name, I'll be on the way like"),
#  (0, ''),
#  (0, 'Mmm, mmm, mmm'),
#  (0, 'Mmm, mmm, mmm'),
#  (0, ''),
#  (0, 'Ayy, ayy'),
#  (6, "I wanna sell what you're buyin'"),
#  (11, 'I wanna feel on your ass in Hawaii'),
#  (7, "I want that jet lag from fuckin' and flyin'"),
#  (8, "Shoot a child in your mouth while I'm ridin'"),
#  (5, 'Oh, oh, oh, why me?'),
#  (12, 'A sign of the times every time that I speak'),
#  (12, 'A dime and a nine, it was mine every week'),
#  (10, "What a time, an incline, God was shinin' on me"),
#  (4, "Now I can't leave"),
#  (7, "And now I'm actin' hella elite"),
#  (8, "Never want the niggas that's in my league"),
#  (12, 'I wanna fuck the ones I envy, I envy'),
#  (0, ''),
#  (6, "Cocaine and drinkin' with your friends"),
#  (11, 'You live in the dark, boy, I cannot pretend'),
#  (8, "I'm not fazed, only here to sin"),
#  (12, "If Eve ain't in your garden, you know that you can"),
#  (0, ''),
#  (10, 'Call me when you want, call me when you need'),
#  (11, "Call me in the morning, I'll be on the way"),
#  (10, 'Call me when you want, call me when you need'),
#  (12, "Call me out by your name, I'll be on the way like"),
#  (0, ''),
#  (6, 'Oh, call me by your name (Mmm, mmm, mmm)'),
#  (8, 'Tell me you love me in private'),
#  (5, 'Call me by your name (Mmm, mmm, mmm)'),
#  (6, "I do not care if you lyin'"),
#  (0, ''),
#  (3, "Well I'm just feelin', mm-uh"),
#  (4, 'I wanna get, mm-uh'),
#  (7, "I'm in my, into my, uh"),
#  (1, "I'm mm, mm"),
#  (2, "I'm still, mm, mm-mm")]
